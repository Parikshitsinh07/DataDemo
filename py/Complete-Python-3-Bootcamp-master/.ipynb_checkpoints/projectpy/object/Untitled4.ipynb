# %%
import pandas as pd
import numpy as np

# %%
df3 = pd.read_csv('test.csv')
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfage1 = df3['Age'].fillna(df3.groupby('Pclass')['Age'].mean()[1])
dfage2 = df3['Age'].fillna(df3.groupby('Pclass')['Age'].mean()[2])
dfage3 = df3['Age'].fillna(df3.groupby('Pclass')['Age'].mean()[3])

# %%
df_new = pd.concat((dfage1,dfage2,dfage3),ignore_index = True) 
df_new
# Out:
# 0       22.00000
# 1       38.00000
# 2       26.00000
# 3       35.00000
# 4       35.00000
#           ...
# 2668    27.00000
# 2669    19.00000
# 2670    25.14062
# 2671    26.00000
# 2672    32.00000
# Name: Age, Length: 2673, dtype: float64

# %%
data={
    'A':[2,3,None,4,2,1],
    'B':[2,4,2,1,3,None]
}
df1=pd.DataFrame(data)

# %%
print(df1)
# Out:
#      A    B
# 0  2.0  2.0
# 1  3.0  4.0
# 2  NaN  2.0
# 3  4.0  1.0
# 4  2.0  3.0
# 5  1.0  NaN

# %%
df1.isnull().sum()
# Out:
# A    1
# B    1
# dtype: int64

# %%
data2={
    'X':[2,3,'x',4,'x',1],
    'Y':[2,4,2,'y',3,'y'],
    'Z':['z',4,'z',2,3,'z']
}
df2=pd.DataFrame(data2)

# %%
ZX = df2[df2['X']=='X']
ZY = df2[df2['Y']=='Y']
ZZ = df2[df2['Z']=='Z']

# %%
ZX
# Out:
# Empty DataFrame
# Columns: [X, Y, Z]
# Index: []
