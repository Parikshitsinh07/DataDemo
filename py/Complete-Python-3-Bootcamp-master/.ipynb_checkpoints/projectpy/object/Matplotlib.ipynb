# %% [markdown]
# linspace use for genret rendom array for Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)#numpy.linspace(start ,stop,num = 50,endpoint = True,retstep = False,dtype = None)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %% [markdown]
# subplots use for  creat a plot

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %% [markdown]
# #### Parts of a Figure and Ther funcation
# Object is subplot Object
# 1. plt.figure(Use of set figure)
# 2. Object.grid(Use of background grid show)
# 3. Object.legend(Use of lebal )
# 4. Object.yaxis.set_minor_locator(Minor tick)
# 5. Object.plot(Use for line chart)
# 6. Object.yaxis.set_minor_formatter(Minor tick label)
# 7. Object.set_ylabel(y par label lagava mate)
# 8. Object.yaxis.set_major_locator(major tick)
# 9. Object.scatter(Markesrs)
# 10. Object.spines(use for border)
# 11. fig.subplots(use for Axes)
# 12. Object.yaxis(yAxis)
# 13. Object.xaxis(xAxis)
# 14. Object.set_xlable(xlabel)
# 15. Object.xaxis.set_minor_formatter(Minor tick label)

# %%
#fig = plt.figure()  # an empty figure with no Axes
fig,ax = plt.subplots(1,2)  # a figure with a single Axes
x1=[2,4,6,8]
y1=[1,3,5,7]
#x2=[2,4,6,8]
y2=[7,5,3,1]
# Set position of bar on X axis 
br1 = np.arange(len(IT)) 
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2] 
ax[0].bar(,)
ax[0].bar(,)
ax[0].grid(alpha=0.9,color="red",animated=True,gapcolor=None,ls=':')
ax[0].legend(['label1', 'label2', 'label3'],loc='best',ncols=1,fontsize='small',labelcolor=['r','y'],title='Selery')#upper right
ax[1].stem([2,4,6,8],[1,3,5,7])
ax[1].grid(alpha=0.2,color="y",animated=False,lw=2.0)
#fig, axs = plt.subplots(1,2)  # a figure with a 2x2 grid of Axes
# a figure with one axes on the left, and two on the right:
#fig, axs = plt.subplot_mosaic([['left', 'right_top'],
 #                             ['left', 'right_bottom']])

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)
print(b_asarray)
# Out:
# [[1 2]
#  [3 4]]

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')
