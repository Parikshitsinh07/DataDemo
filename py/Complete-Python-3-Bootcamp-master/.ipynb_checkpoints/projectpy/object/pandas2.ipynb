# %%
import pandas as pd

# %%
mydata = {"Roll No":[101,102,103,104],"Sub-1 Marks":[68,78,91,85]}
#         column-name

# %%
print(mydata)
# Out:
# {'Roll No': [101, 102, 103, 104], 'Sub-1 Marks': [68, 78, 91, 85]}

# %%
for i,j in mydata.items():
    print(i,"have this items: ",j)
# Out:
# Roll No have this items:  [101, 102, 103, 104]
# Sub-1 Marks have this items:  [68, 78, 91, 85]

# %%
print(type(mydata))
# Out:
# <class 'dict'>

# %%
mydata = {"Roll No":[101,102,103,104],"Sub-1 Marks":[68,78,91,85],
          "Sub-2 Marks":[68,48,91,61],"Sub-3 Marks":[60,57,68,36]}

# %%
keyStore = mydata.keys()

# %%
for i in keyStore:
    print(i)
# Out:
# Roll No
# Sub-1 Marks
# Sub-2 Marks
# Sub-3 Marks

# %%
for i in mydata.values():
    print(i)
# Out:
# [101, 102, 103, 104]
# [68, 78, 91, 85]
# [68, 48, 91, 61]
# [60, 57, 68, 36]

# %%
mydata.items()
# Out:
# dict_items([('Roll No', [101, 102, 103, 104]), ('Sub-1 Marks', [68, 78, 91, 85]), ('Sub-2 Marks', [68, 48, 91, 61]), ('Sub-3 Marks', [60, 57, 68, 36])])

# %%
mydata.get("Roll No")
# Out:
# [101, 102, 103, 104]

# %%
# create the data frame
df = pd.DataFrame(mydata)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df)
# Out:
#    Roll No  Sub-1 Marks  Sub-2 Marks  Sub-3 Marks
# 0      101           68           68           60
# 1      102           78           48           57
# 2      103           91           91           68
# 3      104           85           61           36

# %%
print(df.loc[0])
# Out:
# Roll No        101
# Sub-1 Marks     68
# Sub-2 Marks     68
# Sub-3 Marks     60
# Name: 0, dtype: int64

# %%
mydata = {"Roll No":[101,102,103,104],"Sub-1 Marks":[68,78,85],
          "Sub-2 Marks":[68,48,91,61],"Sub-3 Marks":[60,57,68,36]}

# %%
pd.DataFrame(mydata) # All arrays must be of the same length
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.DataFrame(mydata) # All arrays must be of the same length
#
# File c:\users\st\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# ...

# %%
mydict = {"deptId":[1,2,3,4,5],
          "deptName":["Science","Commerce","Arts","Diploma","IIT"],
          "cource":["BCA,MCA","B-COM,M-COM","BA,MA","Computer-engineering.","Software-Developer"]}

# %%
df = pd.DataFrame(mydict)

# %%
print(df)

# %%
df.head(1)

# %%
df.head(3)

# %%
df.tail()

# %%
df.tail(2)
# Out:
#    Roll No  Sub-1 Marks  Sub-2 Marks  Sub-3 Marks
# 2      103           91           91           68
# 3      104           85           61           36

# %%
df.columns
# Out:
# Index(['Roll No', 'Sub-1 Marks', 'Sub-2 Marks', 'Sub-3 Marks'], dtype='object')

# %%
df['Roll No']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# Name: Roll No, dtype: int64

# %%
df['Sub-1 Marks']
# Out:
# 0    68
# 1    78
# 2    91
# 3    85
# Name: Sub-1 Marks, dtype: int64

# %%
df.dtypes
# Out:
# Roll No        int64
# Sub-1 Marks    int64
# Sub-2 Marks    int64
# Sub-3 Marks    int64
# dtype: object

# %%
a = df.values
import numpy as np

# %%
a.argmax
# Out:
# <function ndarray.argmax>

# %%
df["Roll No"].sum()
# Out:
# 410

# %%
df['%of Sub'] = ((df['Sub-1 Marks']+df['Sub-2 Marks']+df['Sub-3 Marks'])/300) * 100

# %%
df.values
# Out:
# array([[101.        ,  68.        ,  68.        ,  60.        ,
#          65.33333333],
#        [102.        ,  78.        ,  48.        ,  57.        ,
#          61.        ],
#        [103.        ,  91.        ,  91.        ,  68.        ,
#          83.33333333],
#        [104.        ,  85.        ,  61.        ,  36.        ,
#          60.66666667]])

# %%
df['New_Col'] = [1,2,3,4]

# %%
df
# Out:
#    Roll No  Sub-1 Marks  Sub-2 Marks  Sub-3 Marks    %of Sub  New_Col
# 0      101           68           68           60  65.333333        1
# 1      102           78           48           57  61.000000        2
# 2      103           91           91           68  83.333333        3
# 3      104           85           61           36  60.666667        4

# %%
df['Total'] = df['Sub-1 Marks']+df['Sub-2 Marks']+df['Sub-3 Marks']

# %%
df
# Out:
#    Roll No  Sub-1 Marks  Sub-2 Marks  Sub-3 Marks    %of Sub  New_Col  Total
# 0      101           68           68           60  65.333333        1    196
# 1      102           78           48           57  61.000000        2    183
# 2      103           91           91           68  83.333333        3    250
# 3      104           85           61           36  60.666667        4    182

# %%
# create col that name is total percentage and find %

df['Total Percentage'] = ((df['Sub-1 Marks']+df['Sub-2 Marks']+df['Sub-3 Marks'])/300)*100

# %%
df
# Out:
#    Roll No  Sub-1 Marks  Sub-2 Marks  Sub-3 Marks    %of Sub  New_Col  Total  \
# 0      101           68           68           60  65.333333        1    196
# 1      102           78           48           57  61.000000        2    183
# 2      103           91           91           68  83.333333        3    250
# 3      104           85           61           36  60.666667        4    182
#
#    Total Percentage
# 0         65.333333
# 1         61.000000
# 2         83.333333
# 3         60.666667

# %%
f = pd.DataFrame({'angles':[0,3,4],
                 'degrees':[360,180,360]})
# index = ['circle','triangel','rectangle']

# %%
f.dtypes
# Out:
# angles     int64
# degrees    int64
# dtype: object

# %%
f
# Out:
#    angles  degrees
# 0       0      360
# 1       3      180
# 2       4      360

# %%
f = pd.DataFrame({'angles':[0,3,4],
                 'degrees':[360,180,360]},index = ['circle','triangel','rectangle'])

# %%
f
# Out:
#            angles  degrees
# circle          0      360
# triangel        3      180
# rectangle       4      360

# %%
# pf = pd.read_csv('http://bit.ly/kaggletrain')
df = pd.read_csv('t.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('http://bit.ly/kaggletrain')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\users\st\appdata\local\programs\python\python39\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File c:\users\st\appdata\local\programs\python\python39\lib\http\client.py:1257, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1256 """Send a complete request to the server."""
# -> 1257 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\users\st\appdata\local\programs\python\python39\lib\http\client.py:1303, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
df.shape

# %%
# write a command to find out the average age of the passanger

# %%
df['Age'].sum()

# %%
df['Age'].count()

# %%
df['Age'].sum()/df.shape[0]

# %%
df['Age'][58]
# Out:
# 5.0

# %%
df['Age'].sum()
# Out:
# 21205.17

# %%
df['Age'].values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
(df['Sex'].values)
# Out:
# array(['male', 'female', 'female', 'female', 'male', 'male', 'male',
#        'male', 'female', 'female', 'female', 'female', 'male', 'male',
#        'female', 'female', 'male', 'male', 'female', 'female', 'male',
#        'male', 'female', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'male', 'female', 'female', 'male', 'male',
#        'male', 'male', 'male', 'female', 'female', 'female', 'female',
#        'male', 'female', 'female', 'male', 'male', 'female', 'male',
#        'female', 'male', 'male', 'female', 'female', 'male', 'male',
#        'female', 'male', 'female', 'male', 'male', 'female', 'male',
#        'male', 'male', 'male', 'female', 'male', 'female', 'male', 'male',
#        'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male',
#        'female', 'male', 'male', 'female', 'male', 'female', 'female',
#        'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male',
# ...

# %%
sexdf = df[df['Pclass'] == 3]

# %%
print(sexdf)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# dataframe
sexdf = df[df['Sex'] == 'male']

# %%
print(sexdf)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
sexdf.shape
# Out:
# (577, 12)

# %%
# frequency for unique values
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sexdf['Pclass'].value_counts()
# Out:
# Pclass
# 3    347
# 1    122
# 2    108
# Name: count, dtype: int64

# %%
sexdf.shape
# Out:
# (577, 12)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sdf = df[(df['Pclass']==1) & (df['Sex']=='female')]

# %%
print(sdf)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sdf = df[(df['Pclass']==1) & (df['Sex']=='female') & (df['Age']<20)]

# %%
print(sdf)
# Out:
#      PassengerId  Survived  Pclass  \
# 136          137         1       1
# 291          292         1       1
# 297          298         0       1
# 307          308         1       1
# 311          312         1       1
# 329          330         1       1
# 435          436         1       1
# 504          505         1       1
# 585          586         1       1
# 689          690         1       1
# 700          701         1       1
# 781          782         1       1
# 853          854         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 136                       Newsom, Miss. Helen Monypeny  female  19.0      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1
# 297                       Allison, Miss. Helen Loraine  female   2.0      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# ...

# %%
string1= "i am a stundet if mca"

# %%
string1.count('i')
# Out:
# 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def surname(x):
    return x.split(',')[0]

# %%
df['Surname'] = df['Name'].apply(surname)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
df.drop(columns='Surname')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(columns='Surname') #inplace =true
# df.drop(clumns = 'Surname',inplace = true)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.insert(4,'Surname',df['Name'].apply(surname))

# %%
df.pop('Surname')
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Surname, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def half_age(x):
    return x/2

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
# mapping 
gender = df['Sex'].map({'male':0,'female':1})
gender
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
# write down a code to add gender column
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df.insert(12,'Gender',df['Sex'].apply(gender))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\users\st\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py:1257, in SeriesApply.apply_compat(self)
#    1256 try:
# -> 1257     result = obj.apply(func, by_row="compat")
#    1258 except (ValueError, AttributeError, TypeError):
#
# File c:\users\st\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:4753, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4634 """
#    4635 Invoke function on values of Series.
#    4636
#    (...)
#    4751 dtype: float64
#    4752 """
# -> 4753 return SeriesApply(
#    4754     self,
#    4755     func,
#    4756     convert_dtype=convert_dtype,
#    4757     by_row=by_row,
#    4758     args=args,
#    4759     kwargs=kwargs,
#    4760 ).apply()
#
# ...

# %%
def gender(x):
    retrun x

# %%
# write a python program to load defferent kind of the file (json, xml, exal etc)
xlsxdf = pd.read_excel("t.xlsx")

# %%
# write a program to count a word in a given string. string funtion return a list
string = "Gujarat Vidyapith"
res = len(string.split())
print (str(res))

# %%
# how to delete column directly in frame dataframe
xlsxdf.drop(columns=["X1: External Intervention"], inplace=True)

# %%
# finction()
# to access an entity from a data frame,lists or any var with multiple values
#

# %%
# 6-12-23
# find out where the values are missing
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
177/891*100
# Out:
# 19.865319865319865

# %%
import matplotlib.category as d
help(d)
# Out:
# Help on module matplotlib.category in matplotlib:
#
# NAME
#     matplotlib.category
#
# DESCRIPTION
#     Plotting of string "category" data: ``plot(['d', 'f', 'a'], [1, 2, 3])`` will
#     plot three points with x-axis values of 'd', 'f', 'a'.
#
#     See :doc:`/gallery/lines_bars_and_markers/categorical_variables` for an
#     example.
#
#     The module uses Matplotlib's `matplotlib.units` mechanism to convert from
#     strings to integers and provides a tick locator, a tick formatter, and the
#     `.UnitData` class that creates and stores the string-to-integer mapping.
#
# CLASSES
#     builtins.object
#         UnitData
#     matplotlib.ticker.Formatter(matplotlib.ticker.TickHelper)
#         StrCategoryFormatter
#     matplotlib.ticker.Locator(matplotlib.ticker.TickHelper)
#         StrCategoryLocator
#     matplotlib.units.ConversionInterface(builtins.object)
#         StrCategoryConverter
#
#     class StrCategoryConverter(matplotlib.units.ConversionInterface)
# ...

# %%
df.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
# from PIL import Image

# import matplotlib.pyplot as plt
# import numpy as np

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()[1]
# Out:
# 38.233440860215055

# %%
type(df.groupby('Pclass')['Age'].mean())
# Out:
# pandas.core.series.Series

# %%
# dfc1 = df[df[d]]

# %%
df['Age'] = df['Age'].fillna(df.groupby('Pclass')['Age'].mean()[1])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
import pandas as pd
df_new = pd.concat((df['Age'].fillna(df.groupby('Pclass')['Age'].mean()),
                   df['Age'].fillna(df.groupby('Pclass')['Age'].mean()),
                   df['Age'].fillna(df.groupby('Pclass')['Age'].mean())),ignore_index=True)

# %%
df_new.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df_new = df

# %%
df_new = df_new.dropna()

# %%
df_new.shape
# Out:
# (202, 12)

# %%
df_new.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data = {
    'A':[2,3,np.nan,4,2,1],
    'B':[2,4,2,1,3,np.nan]
}

# %%
df1 = pd.DataFrame(data)

# %%
print(df1)
# Out:
#      A    B
# 0  2.0  2.0
# 1  3.0  4.0
# 2  NaN  2.0
# 3  4.0  1.0
# 4  2.0  3.0
# 5  1.0  NaN

# %%
df1.isnull().sum()
# Out:
# A    1
# B    1
# dtype: int64

# %%
df1['B'][5] = 5

# %%
df1
# Out:
#      A    B
# 0  2.0  2.0
# 1  3.0  4.0
# 2  NaN  2.0
# 3  4.0  1.0
# 4  2.0  3.0
# 5  1.0  5.0

# %%
pd.concat((zx,zy,zz)).reset_index().sort_values('index',ignore_index=True).drop('index',axis=1)
# Out:
#    a   b
# 0  1  x1
# 1  5  y1
# 2  2  z1
# 3  2  x2
# 4  7  y2
# 5  5  z2
# 6  3  x3
# 7  9  y3
# 8  7  z3

# %%
data1 = {'a':[1,2,3],'b':['x1','x2','x3']}
zx = pd.DataFrame(data1)

data2 = {'a':[5,7,9],'b':['y1','y2','y3']}
zy = pd.DataFrame(data2)

data3 = {'a':[2,5,7],'b':['z1','z2','z3']}
zz = pd.DataFrame(data3)

# %%
zx
# Out:
#    a   b
# 0  1  x1
# 1  2  x2
# 2  3  x3

# %%
zy
# Out:
#    a   b
# 0  5  y1
# 1  7  y2
# 2  9  y3

# %%
zz
# Out:
#    a   b
# 0  2  z1
# 1  5  z2
# 2  7  z3

# %%
pd.concat((zx,zy,zz))
# Out:
#    a   b
# 0  1  x1
# 1  2  x2
# 2  3  x3
# 0  5  y1
# 1  7  y2
# 2  9  y3
# 0  2  z1
# 1  5  z2
# 2  7  z3

# %%
pd.concat((zx,zy,zz)).reset_index()
# Out:
#    index  a   b
# 0      0  1  x1
# 1      1  2  x2
# 2      2  3  x3
# 3      0  5  y1
# 4      1  7  y2
# 5      2  9  y3
# 6      0  2  z1
# 7      1  5  z2
# 8      2  7  z3

# %%
pd.concat((zx,zy,zz)).reset_index().sort_values('index',ignore_index=True)
# Out:
#    index  a   b
# 0      0  1  x1
# 1      0  5  y1
# 2      0  2  z1
# 3      1  2  x2
# 4      1  7  y2
# 5      1  5  z2
# 6      2  3  x3
# 7      2  9  y3
# 8      2  7  z3

# %%
pd.concat((zx,zy,zz)).reset_index().sort_values('index',ignore_index=True).drop('index',axis=1)
# Out:
#    a   b
# 0  1  x1
# 1  5  y1
# 2  2  z1
# 3  2  x2
# 4  7  y2
# 5  5  z2
# 6  3  x3
# 7  9  y3
# 8  7  z3
