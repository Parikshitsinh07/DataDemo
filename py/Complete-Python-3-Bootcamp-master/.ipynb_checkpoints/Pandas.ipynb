# %% [markdown]
# ## Pandas

# %% [markdown]
# ##### 4-12-2023

# %% [markdown]
# ### What is Pandas?
# - PANDAS : Panel Data
# - Pandas is Python Data Analysis Library
# - It is a very important library used for working with data sets
# - It is used for handling data that convert data into rows and columns
# - It provide functions to load the data
# - It is built on top of the NumPy package
# - __pip install pandas__

# %% [markdown]
# ### Importance of Pandas
# - Pandas allows us to analyze big data and make conclusions based on statistical theories
# - Pandas can clean messy data sets, and make them readable and relevant
# - Relevant data is very important in data science.

# %% [markdown]
# ### What is data frame in Pandas?
# - A DataFrame is a data structure that organizes data into a 2-dimensional table of rows and columns, much like a spreadsheet
# - DataFrames are one of the most common data structures used in modern data analytics
# - They are a flexible and intuitive way of storing and working with data.
# - __DataFrame = {"Column_name":[value]}__ <br>
#   &emsp; DataFrame - representing data frame dictionary name <br>
#   &emsp; Column_name - representing column name, that written in double quotation  <br>
#   &emsp; __:__ - column name and value separated by '__:__' <br>
#   &emsp; value - values wrritten in '[]', values are one kind of list, each values saperated by '__,__' <br>
# - Using DataFrame() function create an empty data frame

# %%
import pandas as pd

# %%
df = pd.DataFrame()
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
std_data = {"Roll No" : [101, 102, 103, 104, 105], 
          "Subject-1 Marks" : [68, 78, 91, 85, 66], 
          "Subject-2 Marks" : [83, 75, 84, 90, 92], 
          "Subject-3 Marks" : [84, 93, 75, 86, 84]}

# %%
df = pd.DataFrame(std_data)

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks
# 0      101               68               83               84
# 1      102               78               75               93
# 2      103               91               84               75
# 3      104               85               90               86
# 4      105               66               92               84

# %%
product = {"Product No" : [201, 202, 203, 204, 205], 
          "Product Name" : ["Pen", "Pencil", "Scale", "Jel Pen", "Rounder"], 
          "Price" : [10, 5, 10, 15, 20], 
           "QTY" : [5, 1, 4, 3, 2], 
          "Manufacturing" : ["NOV-2023", "OCT-2023", "JUL-2023", "SEP-2023", "JUL-2023"]}

# %%
pdf = pd.DataFrame(product)

# %%
pdf
# Out:
#    Product No Product Name  Price  QTY Manufacturing
# 0         201          Pen     10    5      NOV-2023
# 1         202       Pencil      5    1      OCT-2023
# 2         203        Scale     10    4      JUL-2023
# 3         204      Jel Pen     15    3      SEP-2023
# 4         205      Rounder     20    2      JUL-2023

# %% [markdown]
# ### head() function

# %%
df.head(2)
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks
# 0      101               68               83               84
# 1      102               78               75               93

# %% [markdown]
# ### tail() function

# %%
df.tail(2)
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks
# 3      104               85               90               86
# 4      105               66               92               84

# %% [markdown]
# ### columns function

# %%
df.columns
# Out:
# Index(['Roll No', 'Subject-1 Marks', 'Subject-2 Marks', 'Subject-3 Marks'], dtype='object')

# %%
df['Roll No']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: Roll No, dtype: int64

# %%
df.dtypes
# Out:
# Roll No            int64
# Subject-1 Marks    int64
# Subject-2 Marks    int64
# Subject-3 Marks    int64
# dtype: object

# %% [markdown]
# ### values function
# - return numpy array

# %%
df.values
# Out:
# array([[101,  68,  83,  84],
#        [102,  78,  75,  93],
#        [103,  91,  84,  75],
#        [104,  85,  90,  86],
#        [105,  66,  92,  84]], dtype=int64)

# %% [markdown]
# ### sum() function

# %%
df.sum()
# Out:
# Roll No            515
# Subject-1 Marks    388
# Subject-2 Marks    424
# Subject-3 Marks    422
# dtype: int64

# %%
df['Subject-1 Marks'].sum()
# Out:
# 388

# %% [markdown]
# ### max() function

# %%
df.max()
# Out:
# Roll No            105
# Subject-1 Marks     91
# Subject-2 Marks     92
# Subject-3 Marks     93
# dtype: int64

# %%
df["Subject-2 Marks"].max()
# Out:
# 92

# %% [markdown]
# ### min() function

# %%
df.min()
# Out:
# Roll No            101
# Subject-1 Marks     66
# Subject-2 Marks     75
# Subject-3 Marks     75
# dtype: int64

# %%
df["Subject-3 Marks"].min()
# Out:
# 75

# %% [markdown]
# ### add column in existing table

# %%
df["Subject-4 Marks"] = [86, 80, 92, 85, 95]

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks  Subject-4 Marks
# 0      101               68               83               84               86
# 1      102               78               75               93               80
# 2      103               91               84               75               92
# 3      104               85               90               86               85
# 4      105               66               92               84               95

# %%
df['Total'] = df['Subject-1 Marks'] + df['Subject-2 Marks'] + df['Subject-3 Marks'] + df['Subject-3 Marks']

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks  \
# 0      101               68               83               84
# 1      102               78               75               93
# 2      103               91               84               75
# 3      104               85               90               86
# 4      105               66               92               84
#
#    Subject-4 Marks  Total
# 0               86    319
# 1               80    339
# 2               92    325
# 3               85    347
# 4               95    326

# %%
df['Total Percentage'] = (df['Total'] * 100) / 400

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks  \
# 0      101               68               83               84
# 1      102               78               75               93
# 2      103               91               84               75
# 3      104               85               90               86
# 4      105               66               92               84
#
#    Subject-4 Marks  Total  Total Percentage
# 0               86    319             79.75
# 1               80    339             84.75
# 2               92    325             81.25
# 3               85    347             86.75
# 4               95    326             81.50

# %%
a = [98, 89, 79, 83, 84]
df.insert(5, "Subject-5 Marks", a)

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks  \
# 0      101               68               83               84
# 1      102               78               75               93
# 2      103               91               84               75
# 3      104               85               90               86
# 4      105               66               92               84
#
#    Subject-4 Marks  Subject-5 Marks  Total  Total Percentage
# 0               86               98    319             79.75
# 1               80               89    339             84.75
# 2               92               79    325             81.25
# 3               85               83    347             86.75
# 4               95               84    326             81.50

# %% [markdown]
# ### remove column in existing table

# %%
df = df.drop(columns=['Subject-5 Marks'])

# %%
df
# Out:
#    Roll No  Subject-1 Marks  Subject-2 Marks  Subject-3 Marks  \
# 0      101               68               83               84
# 1      102               78               75               93
# 2      103               91               84               75
# 3      104               85               90               86
# 4      105               66               92               84
#
#    Subject-4 Marks  Total  Total Percentage
# 0               86    319             79.75
# 1               80    339             84.75
# 2               92    325             81.25
# 3               85    347             86.75
# 4               95    326             81.50

# %% [markdown]
# ### What is index in pandas?
# - index has no column name
# - index is parameter that is list

# %%
f = pd.DataFrame({"angle" : [0, 3, 4], "degrees" : [360, 180, 360]}, 
                 index = ['circle', 'triangle', 'rectangle'])

# %%
f
# Out:
#            angle  degrees
# circle         0      360
# triangle       3      180
# rectangle      4      360

# %% [markdown]
# # access online data

# %%
csvdf = pd.read_csv("t.csv")

# %%
csvdf = pd.read_csv("http://bit.ly/kaggletrain")

# %%
csvdf.head()

# %%
csvdf.tail()

# %% [markdown]
# ### size() function

# %%
csvdf.size

# %% [markdown]
# ### shape function

# %%
csvdf.shape[0]

# %% [markdown]
# ### write a command to findout avarage age of the pasenger

# %%
b = csvdf["Age"].sum()
print(b)
avg = b/891
print(avg)

# %%
avg = csvdf["Age"].sum() / df.shape[0]
print(avg)

# %%
csvdf["Age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### unique() funtion
# - check unique value

# %%
csvdf["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
csvdf["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### series
# - what is series in pandas datatype
#  - pandas series is a one dimentional labeled array capble of holding data of any (integer, float, python, objects etc.)
#   - sytax : ser = pd.Series(dara)
#  - creating a series from an array : in order to crete a series from array, we have to import a numpy module and have to use aeeay() function
#   - data = np.array(['p','y','t','h','o','n'])
#   - ser = pd.Series(data)
#  - creating a series from list : in order to crete a series from list, we have to first create a list after that we can create a series from list
#   - list = ['p','y','t','h','o','n']
#   - ser = pd.Series(list)me

# %% [markdown]
# - difference between series and dataframe
#  -
# - how to convert the serice into data frame

# %% [markdown]
# ## create 2 different dataframe based on the pacenger sex (male, female)

# %%
maledf = csvdf[csvdf["Sex"] == 'male']    #return series

# %%
maledf
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
femaledf = csvdf[csvdf["Sex"] == 'female']

# %%
femaledf
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## create 3 different dataframe based on the pacenger class (1,2,3)

# %%
d1df = csvdf[csvdf["Pclass"] == 1]

# %%
d1df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d2df = csvdf[csvdf["Pclass"] == 2]

# %%
d2df
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
d3df = csvdf[csvdf["Pclass"] == 3]

# %%
d3df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ### value_counts()
# - for check frequency

# %%
csvdf['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
csvdf['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
csvdf['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# #### 5-12-2023
# - frequency - for categorical data
# - filterring - logical if
# - split function
# - how to saperate the surname
# - apply function - to apply any other function over whole dataset
# - map function - for computerise data convert label into numerical - map dictionary - key : category name - value : numarical data

# %%
fdf = csvdf[(csvdf["Pclass"] == 3) & (csvdf["Sex"] == "female")]

# %%
fdf
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
def surname(x):
    return x.split(',')[0]

# %%
csvdf['Surname'] = csvdf['Name'].apply(surname)

# %%
csvdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
csvdf =csvdf.drop(columns = ["Surname"])

# %%
csvdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
csvdf.insert(4, 'Surname', csvdf['Name'].apply(surname))

# %%
csvdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name    Surname     Sex  \
# 0                              Braund, Mr. Owen Harris     Braund    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    Cumings  female
# 2                               Heikkinen, Miss. Laina  Heikkinen  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   Futrelle  female
# 4                             Allen, Mr. William Henry      Allen    male
# ..                                                 ...        ...     ...
# ...

# %%
def half_age(age):
    return age/2

# %%
csvdf.insert(7, 'Half Age', csvdf['Age'].apply(half_age))

# %%
csvdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
gender = csvdf['Sex'].map({'male' : 0, 'female' : 1})
gender
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
csvdf.insert(6, 'Gender', gender)

# %%
csvdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Gender  \
# 0                              Braund, Mr. Owen Harris    male  22.0       0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %% [markdown]
# #### write a python program to load defferent kind of the file (json, xml, exal etc)

# %%
xlsxdf = pd.read_excel("t.xlsx")

# %%
xlsxdf
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %% [markdown]
# #### create an dataframe where passenger class = 1 & sex = female

# %% [markdown]
# #### write a program to count a word in a given string. string funtion return a list

# %%
string = "Gujarat Vidyapith"
res = len(string.split())
print (str(res))
# Out:
# 2

# %% [markdown]
# #### how to delete column directly in frame dataframe

# %%
xlsxdf.drop(columns=["X1: External Intervention"], inplace=True)

# %%
xlsxdf.columns
# Out:
# Index(['Country', 'Year', 'Rank', 'Total', 'S1: Demographic Pressures',
#        'S2: Refugees and IDPs', 'C3: Group Grievance',
#        'E3: Human Flight and Brain Drain', 'E2: Economic Inequality',
#        'E1: Economy', 'P1: State Legitimacy', 'P2: Public Services',
#        'P3: Human Rights', 'C1: Security Apparatus',
#        'C2: Factionalized Elites'],
#       dtype='object')

# %% [markdown]
# #### calculate half-age funtion and insert a column after the age into given data frame
